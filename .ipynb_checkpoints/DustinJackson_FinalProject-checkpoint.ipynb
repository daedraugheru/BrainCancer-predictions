# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
image_size = (128, 128)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'C:\\Users\\daedr\\OneDrive\\Documents\\Masters Courses\\IT\\IST691\\Project\\Training',
    validation_split = 0.2,
    subset = 'training',
    seed = 1337,
    image_size = image_size,
    batch_size = batch_size,

    label_mode = "categorical",
    labels = "inferred",
    class_names = ("glioma", "meningioma", "notumor", "pituitary")
)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'C:\\Users\\daedr\\OneDrive\\Documents\\Masters Courses\\IT\\IST691\\Project\\Training',
    validation_split = 0.2,
    subset = 'validation',
    seed = 1337,
    image_size = image_size,
    batch_size = batch_size,

    label_mode = "categorical",
    labels = "inferred",
    class_names = ("glioma", "meningioma", "notumor", "pituitary")
)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    'C:\\Users\\daedr\\OneDrive\\Documents\\Masters Courses\\IT\\IST691\\Project\\Testing',
    validation_split = 0,
    seed = 1337,
    image_size = image_size,
    batch_size = batch_size,

    label_mode = "categorical",
    labels = "inferred",
    class_names = ("glioma", "meningioma", "notumor", "pituitary")
)
# Out:
# Found 1311 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

# specifying the size of the plot
plt.figure(figsize = (10, 10))

# outer for loop to select images and labels from dataset
# train_ds.take(1) selects the first batch of 32 images
for images, labels in train_ds.take(1):

    # inner for loop for visualizing images in grid
    for i in range(9):

        # specifying the subplot parameters and the place to display
        # first two parameters are used for rows and columns
        ax = plt.subplot(3, 3, i + 1)
        # plt.imshow is a function from matplotlib used for showing image as plots
        plt.imshow(images[i].numpy().astype('uint8'))
        # priting class of image as title



        
        #plt.title(int(labels[i]))
        plt.title(labels[i])



        
        # turning off the axis
        plt.axis('off')

# %%
# pre-fetching training and validation data
train_ds = train_ds.prefetch(buffer_size = 32)
val_ds = val_ds.prefetch(buffer_size = 32)

# %%
type(train_ds)
# Out:
# tensorflow.python.data.ops.prefetch_op._PrefetchDataset

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
num_classes = 4

model_cnn = keras.Sequential(
    [
        keras.Input(shape=(128,128,3)),
        tf.keras.layers.Rescaling(1./255),  # Normalize pixel values
        tf.keras.layers.Conv2D(32, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(64, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        #additional layers from the first run attempts
        tf.keras.layers.Conv2D(128, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(64, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(32, 3, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        #end additional layers from first run attempts
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(num_classes, activation='softmax') 
    ]
)

model_cnn.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_4 (Rescaling)              │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 61, 61, 64)          │          18,496 │
# ...

# %%
import matplotlib.pyplot as plt

# %%
#keras.utils.plot_model(model_cnn, show_shapes=True)

# %%
epochs = 25

model_cnn.compile(
    optimizer = keras.optimizers.Adam(1e-3),
    loss = 'binary_crossentropy',
    metrics = ['accuracy'],
)

# %%
results = model_cnn.fit(
    train_ds, epochs = epochs, validation_data = val_ds
)
# Out:
# Epoch 1/25
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.9977 - loss: 0.0118 - val_accuracy: 0.9387 - val_loss: 0.2188
# Epoch 2/25
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.9997 - loss: 0.0064 - val_accuracy: 0.9571 - val_loss: 0.1771
# Epoch 3/25
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 1.0000 - loss: 2.4833e-04 - val_accuracy: 0.9580 - val_loss: 0.1808
# Epoch 4/25
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 60ms/step - accuracy: 1.0000 - loss: 9.2463e-05 - val_accuracy: 0.9606 - val_loss: 0.1867
# Epoch 5/25
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 1.0000 - loss: 3.0531e-05 - val_accuracy: 0.9615 - val_loss: 0.1888
# Epoch 6/25
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 1.0000 - loss: 1.9851e-05 - val_accuracy: 0.9615 - val_loss: 0.1904
# Epoch 7/25
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 1.0000 - loss: 1.6060e-05 - val_accuracy: 0.9615 - val_loss: 0.1919
# Epoch 8/25
# ...

# %%
score = model_cnn.evaluate(test_ds, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.14066267013549805
# Test accuracy: 0.9748283624649048
